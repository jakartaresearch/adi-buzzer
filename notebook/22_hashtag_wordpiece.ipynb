# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE, WordPiece
from tokenizers.trainers import BpeTrainer, WordPieceTrainer
from tokenizers.pre_tokenizers import Whitespace

# %%
trainer = WordPieceTrainer(special_tokens=["[UNK]", "[CLS]", "[SEP]", "[PAD]", "[MASK]"])
tokenizer = Tokenizer(WordPiece())
tokenizer.pre_tokenizer = Whitespace()

# %%
trainer.

# %%
tokenizer.train(trainer, ["../data/tokenizers/hashtag_raw.txt"])

# %%
tokenizer.get_vocab_size()
# Out:
# 9816

# %%
tokenizer.get_vocab()
# Out:
# {'##islam': 2238,
#  '##tas': 2138,
#  '##ebasaktip': 9305,
#  'belie': 6190,
#  'gugat4nies': 8212,
#  'kabupat': 3637,
#  'fri': 2641,
#  'babyc': 8710,
#  'covid': 174,
#  'massagebandung': 3844,
#  'urus': 2502,
#  'khalif': 8238,
#  'dampingi': 8195,
#  'sa': 261,
#  'plusx': 8509,
#  'spectaxcular2020': 8673,
#  'semuab': 6175,
#  'stop': 340,
#  'ku': 606,
#  'mandiricard': 6518,
#  '##cer': 5023,
#  'low': 2711,
#  '##onom': 416,
#  'gorontalo': 9629,
#  'jandamontok': 8055,
#  'prim': 2778,
#  'banser': 1114,
#  '##utri': 2271,
#  'swabhu': 9009,
#  '##jent': 2962,
#  'negeri': 408,
#  'aceof': 7217,
#  'illeg': 8840,
#  '##tu': 1214,
#  '##ester': 3265,
#  'terimakasih': 1909,
#  'album': 6070,
#  'launch': 8252,
#  'khalifah': 9690,
#  '##ivevib': 6987,
#  'berlabuh': 8023,
#  '##angm': 3101,
#  'paytren': 8295,
#  '##bang': 466,
#  'ditjenimigrasi': 7205,
#  '##udin': 5901,
#  'wayang': 3825,
#  'layanan': 4361,
#  '##imku': 5578,
#  'danc': 1991,
#  'polripeduli': 5844,
#  'rock': 2790,
#  'dpdri': 4163,
#  'siber': 2081,
#  '##abah': 2267,
#  'ssdm': 2083,
#  'vcstrust': 9054,
#  '##fa': 1421,
#  'kiv': 4317,
#  'android': 7742,
#  '##distancing': 2157,
#  '##isiator': 3329,
#  'armanasmarasyarifuddin': 9309,
#  'prestasi': 5710,
#  'faktaberitafakta': 9768,
#  '##arch': 1743,
#  'ceritaseksterbaru': 8102,
#  'to300k': 9371,
#  'ramle': 6097,
#  '##ina': 402,
#  'regrann': 8994,
#  'disabilitas': 9440,
#  '##abonation': 5643,
#  '##ineka': 2221,
#  'serius': 3711,
#  'pold': 777,
#  'maafkan': 8263,
#  'papuah': 6150,
#  '##ebasakti': 6445,
#  '##italisme': 5379,
#  'kolaborasinergi': 7906,
#  'kr': 2027,
#  'taypaksmg': 8135,
#  'mundurlah': 7037,
#  'hakiki': 8216,
#  'meny': 3286,
#  '##ah': 89,
#  'sabungayam': 7155,
#  'bidhumaspoldaj': 8122,
#  'rugi': 9002,
#  'semarang': 6172,
#  'halu': 2665,
#  '##auty': 7062,
#  '##ancasi': 378,
#  'jagajakartabersih': 9726,
#  'indi': 874,
#  'valkyrie48': 9062,
#  '##ovasi': 882,
#  't88': 4587,
#  '##bareng': 6240,
#  'susu': 7951,
#  'stray': 8036,
#  '##escl': 5421,
#  'potret': 8302,
#  '##eart': 2878,
#  '##view': 5109,
#  '##erintah': 1230,
#  'token': 7396,
#  '##nersetiadoktergigi': 9652,
#  'indonesiaterserah': 8048,
#  'boycott': 9659,
#  'dong': 2622,
#  'karang': 4323,
#  'penghianat': 6331,
#  '##151': 2436,
#  'bispak': 6274,
#  '##apa': 1087,
#  'sukoharj': 1299,
#  '##5987': 5135,
#  '##ife': 896,
#  'akad': 6130,
#  'raden': 8990,
#  'petani': 2555,
#  '##umham': 2249,
#  '##law': 505,
#  'merdeka': 1006,
#  'how': 4241,
#  'islam': 327,
#  'sdmpoldasulsel': 9031,
#  'bes': 1965,
#  'diabet': 3232,
#  'ka': 2685,
#  'sumber': 6745,
#  'wish': 2849,
#  '##angat': 870,
#  'gerakanlit': 6858,
#  'tangan': 2094,
#  'dengerin': 3545,
#  'thank': 6102,
#  'jogobumiproklamator': 9517,
#  'bagi': 1969,
#  '##ikeb': 5613,
#  'staf': 2304,
#  '##leman': 4669,
#  '##edan': 1099,
#  'portal': 3912,
#  'humanis': 7891,
#  '##adelph': 5574,
#  'cre': 4109,
#  'keperawan': 6737,
#  'teknologi': 8611,
#  '##tack': 4808,
#  'under': 5895,
#  'pow20': 7947,
#  '##_05': 5120,
#  'khilafahajaranislam': 8437,
#  '##ob': 187,
#  'purbaleun': 8510,
#  'dampak': 8194,
#  '##angdan': 5358,
#  'jun16': 8229,
#  'suryaputranta': 3857,
#  '##ikalteng': 5619,
#  'dispen': 6923,
#  '##bab': 4972,
#  '##lkkota': 3827,
#  'france': 8781,
#  'partnersex': 9576,
#  '##intas': 3317,
#  '##po': 4697,
#  'tampil': 3934,
#  '##rakyat': 1676,
#  'jangan': 500,
#  'kalimat': 7792,
#  '##rast': 4743,
#  '##asac': 5337,
#  '74': 1957,
#  '##m_': 4771,
#  'ganjar': 2548,
#  '##pus': 2882,
#  'togelindonesia': 6478,
#  'dicium': 9162,
#  'dekat': 2445,
#  'sedap66': 8528,
#  'humaspoldab': 7196,
#  '##ingtopic': 8387,
#  'integritas': 5468,
#  'dewi': 8192,
#  'futsalindonesia': 8209,
#  'selfreminder': 9252,
#  'persebaya': 7183,
#  'believe': 9245,
#  '##16': 2196,
#  '##bit': 4968,
#  'pmibany': 7132,
#  'sumbang': 6747,
#  '##jitu': 1708,
#  'utk': 2450,
#  'merauke': 8462,
#  'berqurban': 9143,
#  '##fromhome': 3953,
#  'puspent': 7258,
#  'jabar': 819,
#  '##erstor': 3355,
#  '##inid': 5250,
#  'berjuta': 8026,
#  '##emen': 1759,
#  'awal': 7219,
#  '##untukselamat': 6595,
#  'badiklat': 7476,
#  '##moda': 4791,
#  'matahari': 6879,
#  '##ta': 506,
#  '##linic': 5935,
#  '##jaindonesia': 5777,
#  'cucitanganpakais': 8577,
#  'geng': 4214,
#  'bayumas': 7848,
#  'sayabayarpajak': 6742,
#  'togelhongkong': 6483,
#  '6': 11,
#  'vcswhats': 6761,
#  'parah': 4476,
#  'ceritaselingk': 7323,
#  '##ea': 2874,
#  'batas': 1971,
#  '##iselcaday': 8373,
#  '##bun': 4967,
#  '##esiasi': 1771,
#  '##me': 372,
#  '##arep': 3057,
#  'makass': 2382,
#  'carut': 8168,
#  'fahira': 3873,
#  'not': 2751,
#  'jat': 2671,
#  'president': 1513,
#  'tahta': 6560,
#  'rumah': 260,
#  'dik': 924,
#  'semangat': 1116,
#  'ngerti': 6256,
#  '##ulut': 3148,
#  'jawatengah': 9444,
#  'masyumi': 6089,
#  'phot': 1636,
#  'sajakmalam': 7957,
#  '##irik': 4760,
#  'bhayangkara': 1973,
#  '##of': 759,
#  'said': 786,
#  '##andimana': 6125,
#  'rabubahagia': 9577,
#  'tekn': 3822,
#  'tik': 1195,
#  'normal': 226,
#  'gamingcommunity': 9539,
#  '##perjuangan': 6442,
#  'ngibul': 2342,
#  '##eritus': 5165,
#  'cuk': 2606,
#  'khilafahdi': 6169,
#  'wajah': 8341,
#  'lawanter': 6287,
#  'merana': 3416,
#  'tukang': 3930,
#  '##ealthy': 7472,
#  'polrihim': 5849,
#  '##uah': 4677,
#  '##jb': 4903,
#  'psbbtransisi': 9733,
#  '##28': 5112,
#  '##edo': 5766,
#  'tanpa': 731,
#  'har': 368,
#  'chinese': 3993,
#  'carat': 4118,
#  'gerbangnews': 9302,
#  '##bersama': 4992,
#  'cail': 4119,
#  '##ku': 854,
#  'humaspoldasulut': 7197,
#  '##latul': 3479,
#  '##menulis': 7287,
#  'sby': 8314,
#  'jenterapadu': 8863,
#  '##mudik': 1692,
#  'pub': 4464,
#  '28': 4035,
#  'nahdlatululama': 8644,
#  '##atintakeabadi': 9114,
#  'pelita': 7141,
#  'positivevibes': 9700,
#  'list': 744,
#  'jadwalcer': 8599,
#  'pr': 137,
#  'pm1gow': 7129,
#  'poker': 831,
#  '##ira': 3187,
#  '##apore': 3126,
#  'kita': 293,
#  '##ihkan': 1481,
#  'harib': 1817,
#  '##post': 2125,
#  'care': 4121,
#  '##mawan': 4782,
#  'jeket': 3881,
#  'worldwar3': 9507,
#  'jokowikerjan': 8408,
#  'merawat': 6410,
#  'pa10kata': 8955,
#  '##ata': 361,
#  'budayas': 3556,
#  'bu': 497,
#  'vitalis': 2841,
#  '##sa': 373,
#  'imlek': 6798,
#  'hexpharm': 8834,
#  'procurement': 9151,
#  'pesantr': 3566,
#  'labbaik': 8898,
#  '##infoj': 5260,
#  '##rumah': 758,
#  'voucher': 9053,
#  'madras': 7925,
#  '##acount': 5841,
#  '##inta': 518,
#  '##nau': 1216,
#  'efpeeshanians': 9684,
#  'polressol': 6368,
#  '##assage': 5344,
#  '##owed': 2287,
#  '##adibandung': 6114,
#  'prediksihkjitu': 8483,
#  'digital': 2300,
#  'happymom': 7818,
#  'ih': 4267,
#  '##edy': 5767,
#  'kanker': 3883,
#  'fatwa': 3870,
#  'vcshot': 6756,
#  '##smove': 7069,
#  '##wasrayas': 6572,
#  'oposisi': 6521,
#  '##ikpapan': 3170,
#  '##e6890': 9078,
#  'langit': 8895,
#  '##aruddin': 5181,
#  'awas': 1331,
#  'segala': 7390,
#  'menangkan': 2457,
#  '##tg': 2923,
#  'terlantar': 8400,
#  'kumparan': 2413,
#  'metrot': 6948,
#  'matanajwa': 8924,
#  '##bumi': 2989,
#  'agenjudi': 2405,
#  'serentak': 1521,
#  'pel': 939,
#  'np': 4408,
#  '##ners': 2152,
#  '##wong': 5043,
#  'home': 642,
#  'budak': 6919,
#  '##_': 70,
#  '##25465987': 9705,
#  'tol': 227,
#  '##pot': 2888,
#  '##aker': 3069,
#  'rrientikong': 7689,
#  '##ro': 757,
#  '##card': 5033,
#  'polantasjatim': 9147,
#  'sukoharjo': 7451,
#  'mor4sik': 8270,
#  '##are': 1429,
#  '##witter': 906,
#  'zakatonline': 7557,
#  'lanj': 4357,
#  'wr': 4611,
#  'alpukat': 3983,
#  'savebintang': 8435,
#  '##sdm': 1699,
#  'bangkrut': 3605,
#  'jihad': 8858,
#  'strong': 3837,
#  '##polisi': 1814,
#  'cal': 2603,
#  'tamat': 4581,
#  'rabusantuy': 7526,
#  'bumnuntukindonesia': 8130,
#  'ek': 454,
#  '##som': 4831,
#  '##az': 1202,
#  'tantebinal': 8489,
#  'anies': 669,
#  '##aseor': 5340,
#  'budayanusantara': 6921,
#  'd_': 4134,
#  '##pet': 1669,
#  '##berny': 6349,
#  'fat': 2638,
#  'madrasah': 9638,
#  'kam': 255,
#  '74thpolrimel': 7835,
#  'no2': 6950,
#  'anaksekolah': 7187,
#  '##iviral': 5973,
#  '##ruk': 4730,
#  'mumet': 8913,
#  'bokepjepang': 7356,
#  'lakukan': 8256,
#  'janj': 1603,
#  '##okol': 1249,
#  'nampang': 8944,
#  'bengkulu': 3665,
#  'onmyoji': 3988,
#  '##yon': 2968,
#  'amnesti': 6186,
#  '##akal': 1235,
#  '##trenggalek': 7717,
#  'bogohkabogor': 9756,
#  'memicu': 6689,
#  '##panggilan': 2126,
#  'to300': 6707,
#  'pijatpasutri': 9426,
#  'human': 2017,
#  'bengkalishits': 8552,
#  'n': 29,
#  '##upi': 1264,
#  '##ersaudara': 6222,
#  'tantemontok': 9372,
#  'borjuis': 7843,
#  'bali': 1576,
#  '##bar': 305,
#  '##sd': 4826,
#  '##jutek': 9097,
#  '##izen': 2402,
#  'lab': 4346,
#  'cac': 2609,
#  'mbah': 2740,
#  'mola': 4388,
#  'investasi': 3832,
#  'kemendes': 3776,
#  '##agharus': 5687,
#  'lamsel': 3611,
#  '##elamat': 3107,
#  '##ue': 2115,
#  'mv': 2720,
#  'tega': 6957,
#  '##ge': 1720,
#  'tppimoj': 7975,
#  '##akta': 5228,
#  'story': 5859,
#  'lupakan': 3671,
#  'lokadata': 7919,
#  '##ile': 3178,
#  'brondongjkt': 8520,
#  '##km': 1710,
#  '##gar': 3032,
#  '##ene': 5236,
#  'samsat': 8317,
#  'dikdin2020': 9490,
#  'divhumaspolri': 8030,
#  'tantehot': 6714,
#  '##vir': 662,
#  'me': 1361,
#  'binorsange': 8564,
#  '##inum': 2218,
#  'jeketiselcaday': 8638,
#  '##ters': 1811,
#  '##eg': 139,
#  'therapy': 9227,
#  'pmin': 7127,
#  'judibolaterpercaya': 9581,
#  '##arga': 625,
#  'partisipasi': 7524,
#  'after10': 8693,
#  'bismillah': 3987,
#  'senyum': 6588,
#  'ta': 834,
#  '##kehidupan': 4963,
#  'cosmopolitan': 3864,
#  '##emut': 5405,
#  '##bak': 856,
#  '##newye': 7072,
#  'ramadhan1441': 3369,
#  'ki': 4302,
#  '##rade': 4744,
#  '##4nies': 1714,
#  '##tni': 2934,
#  '##rind': 4740,
#  '##eberagaman': 9154,
#  'aslinya': 3539,
#  'sayapercayajokowi': 9807,
#  'aksi': 519,
#  'didzol': 6613,
#  'nagajitu': 8940,
#  'piece98': 8980,
#  'barokah': 6076,
#  'vcsbug': 3515,
#  'percaya': 1104,
#  '##etnam': 5753,
#  '##amic': 5310,
#  'omnibuslawdorongekonomi': 9413,
#  'belik': 6189,
#  '##kasino': 4958,
#  'kabartangsel': 7241,
#  'kapitalis': 3526,
#  '##pe': 2118,
#  'instagramdown': 7618,
#  'wonderful': 1929,
#  'polriped': 3235,
#  '##pharm': 7560,
#  'jancukers': 8859,
#  'pasar': 2368,
#  'humanity': 7892,
#  'curangi': 7856,
#  'kebersamaan': 9294,
#  'komando': 3308,
#  'energi': 1005,
#  '##smg': 7067,
#  'matt': 3547,
#  'didalem': 6614,
#  '##pak': 617,
#  '##hi': 2183,
#  'jawa': 1532,
#  'pati': 4469,
#  'presidenku': 6914,
#  '##server': 6414,
#  'komunisme': 2372,
#  '##ka': 2974,
#  '##ilirik': 5646,
#  '##hy': 860,
#  'podcast': 3909,
#  'd__19': 8755,
#  'polisihumanis': 6902,
#  'hengg': 4247,
#  'timpeng': 6751,
#  'jaw': 742,
#  '##mun': 2911,
#  '##ena': 3072,
#  'mamahdedeh': 8269,
#  'anak': 994,
#  '##upa': 3227,
#  'estate': 8775,
#  'produksi': 7301,
#  '##manis': 3651,
#  '##ass': 1756,
#  'availm': 7222,
#  '##ayanan': 2384,
#  'hakim': 8215,
#  'kepri': 1302,
#  'ndik': 4421,
#  'otolokaid': 8147,
#  'berdaulat': 9138,
#  'minggupagi': 7248,
#  '[CLS]': 1,
#  'otol': 2063,
#  'disiplinpolahidupbaru': 9375,
#  '##pon': 4699,
#  'keselamat': 6626,
#  'holding': 8219,
#  'kultwitperin': 8883,
#  'ked': 822,
#  '##ibul': 2293,
#  'red': 1642,
#  'menuju15mei': 9466,
#  'dan': 738,
#  '##mengarungiasa': 9083,
#  'siapuntukselamat': 6610,
#  '##alisong': 1492,
#  '##fullser': 7170,
#  '08': 4029,
#  'cewekbook': 7097,
#  'of1929': 7252,
#  '##abar': 588,
#  'nagih': 4433,
#  'vcscrot': 8063,
#  'humanior': 7893,
#  'treat': 4589,
#  '##ag': 131,
#  'pijathot': 6883,
#  '##agia': 1784,
#  'elevate': 9469,
#  '##siplin': 556,
#  'waspadaharustapitakutjangan': 9478,
#  'apresiasi': 3859,
#  'bandarbola': 3487,
#  '##cepat': 5035,
#  'bandardarattogel': 8482,
#  '##festival': 9102,
#  '##way': 5040,
#  'hast': 2663,
#  '##ubung': 5812,
#  'a31': 8696,
#  'rektorwalisong': 8071,
#  'lb': 4338,
#  'silaturahmi': 4022,
#  '##ackout': 6304,
#  'pijatvitalitas': 8506,
#  'rabubah': 7525,
#  'mus': 457,
#  'arus': 6454,
#  'vog': 4603,
#  'kemalajateng': 9206,
#  '##indra': 1490,
#  'tang': 2816,
#  '##mak': 4774,
#  '##jun': 2956,
#  'dultiarasong': 9564,
#  'cmd3': 8730,
#  '##ya': 216,
#  'pbroker': 8978,
#  '##isebelumberguna': 9131,
#  'hizbuttahrir': 9772,
#  '##how': 5062,
#  'were': 4624,
#  'pal': 428,
#  'sandiaga': 7158,
#  '##aniberkarya': 9112,
#  'melejit': 6327,
#  'mang': 4370,
#  'lebihawall': 6912,
#  '##witperin': 6894,
#  '##mal': 4776,
#  'z': 41,
#  'positivevib': 8309,
#  '##esi': 113,
#  'kho': 4331,
#  'palangm': 6469,
#  'sinarhari': 6888,
#  'kiostix': 3888,
#  '##akzulkan': 5234,
#  'pemuda': 3336,
#  'wamen': 8339,
#  '##obarj': 5930,
#  '8togel': 4044,
#  'gil': 4212,
#  '##gig': 5087,
#  '##tb': 2922,
#  'bandarlivedingdong': 9357,
#  'namaku_': 8290,
#  '##arted': 5885,
#  'kakifly': 8241,
#  'advent': 6662,
#  'pijatbandung': 6881,
#  '##uhut': 629,
#  'festival': 2497,
#  '##ard': 1739,
#  '##d3': 4879,
#  'pokeronlineindonesia': 8519,
#  'jadisarjananusamandi': 9568,
#  '##abayah': 5637,
#  'sobatambyar': 6402,
#  'surabayah': 6474,
#  '##edics': 6413,
#  '##agoan': 1785,
#  '##pdeltasi': 6831,
#  'abaikan': 6868,
#  'gurih': 7880,
#  '2020': 1133,
#  'berita': 544,
#  '##dog': 4884,
#  'semeru': 3343,
#  '##isiapbantu': 6122,
#  'lanjutkan': 8905,
#  'puncak': 7140,
#  'can': 2600,
#  'bakti': 2428,
#  'meng': 1620,
#  'shimizu': 9256,
#  'kota': 2035,
#  'ekstasi': 3440,
#  'palestina': 6859,
#  'bea': 6787,
#  'literasiindonesia': 7465,
#  'mining4': 8516,
#  'berlalulintas_2020': 9654,
#  'polriuntukindonesia': 3236,
#  'lalinbandung': 7511,
#  'folbacknkri': 8787,
#  '##out': 2905,
#  'populer': 8966,
#  'polresbang': 6366,
#  'unsoedjutek': 9183,
#  '##ja': 153,
#  'komisi': 6052,
#  'keliling': 3476,
#  '##rat': 657,
#  'mattter': 8503,
#  'univet': 8394,
#  'will': 7554,
#  '##inc': 3073,
#  'kuliah': 3886,
#  'pg': 4455,
#  'fn': 4177,
#  '##ahasiswa': 5297,
#  'ker': 501,
#  '##seljuara': 6537,
#  'yangs': 2856,
#  '##info': 2222,
#  '##gila': 5092,
#  'iphonesia': 8850,
#  '##channel': 3010,
#  'glamor': 8812,
#  '##iinfo': 4762,
#  'needs': 8292,
#  'benc': 811,
#  '##esm_': 5423,
#  'ramadan': 1001,
#  'psi': 2065,
#  '##emenagharus': 7726,
#  '##ird': 5679,
#  'pacara': 7683,
#  '##tikan': 2933,
#  '##sangek': 4846,
#  '##usi': 262,
#  '##anun': 5145,
#  '##wakafpercikaniman': 8365,
#  '##ssolo': 4851,
#  '##papan': 1561,
#  'hidupsehat': 6930,
#  'selamatkansitif': 7594,
#  'cend': 1981,
#  '##sat': 2936,
#  '##parah': 4714,
#  'buc': 4085,
#  'hex': 4250,
#  '##sg': 2140,
#  'berk': 512,
#  '##493': 3951,
#  'kant': 4310,
#  'kawulamoda': 6390,
#  '##idup': 492,
#  'eidmubarak2020': 8565,
#  'ngakakkocakvideo': 8562,
#  'napitupulu': 9785,
#  'satlantaspolresjayapura': 9722,
#  'liverpoolchampion': 8043,
#  'luculucu': 6682,
#  'hor': 4235,
#  'lensamata': 9637,
#  'satuklik': 6830,
#  'weloveb': 7985,
#  'ganj': 2009,
#  'wamendes': 8340,
#  'dipercepat': 8035,
#  'kolesterol': 9633,
#  'bersamalawan': 1907,
#  'transformasi': 2420,
#  'heart': 4260,
#  'talaud': 9048,
#  'aswaja': 6863,
#  '##aku_': 7725,
#  'jandasurabaya': 8478,
#  'unmas': 5893,
#  'ade': 3492,
#  '##solusi': 4837,
#  '##brata': 8003,
#  '##antura': 2286,
#  'ravio': 7145,
#  'terjaga': 5956,
#  'explore': 7877,
#  'cimahi': 8735,
#  'pijat': 692,
#  'ojol': 3814,
#  'gigol': 2547,
#  'kad': 821,
#  'puisipend': 7470,
#  'amburadul': 9377,
#  'enggar': 6996,
#  'soon': 7529,
#  'fair2019': 8603,
#  'wil': 1395,
#  'bidhumas': 2494,
#  'pasuruan': 6531,
#  'suh': 2804,
#  '##e': 45,
#  '##antono': 5726,
#  'iph': 4279,
#  'sejarah': 1524,
#  '##ebukan': 3208,
#  'birosdmpoldajateng': 8551,
#  '##alista': 6245,
#  '##anysur': 7172,
#  'infosi': 3299,
#  'jember': 2681,
#  '##yum': 4928,
#  'korupsi': 555,
#  '##enik': 5239,
#  '##ocr': 3345,
#  'united': 2524,
#  'korupsi62': 6651,
#  'jap': 2023,
#  'protokolkesehatan': 7605,
#  'ene': 6356,
#  '##polrimel': 6552,
#  'backstreet': 7851,
#  'harilahirpancasila': 3995,
#  'plus': 3564,
#  'sepak': 1560,
#  'pek': 1046,
#  '##alih': 5269,
#  'hiz': 4248,
#  '##rutan': 7286,
#  'uinwalisong': 7977,
#  '##a': 42,
#  'b2020': 4078,
#  'play': 1534,
#  'ruhut': 2791,
#  'infok': 3297,
#  'kem': 212,
#  'malam': 1364,
#  '##is': 100,
#  '##arasamaawan': 7408,
#  'menikmati': 9202,
#  '##ivalk': 5970,
#  '##angkah': 6007,
#  'kec': 4320,
#  'sek': 944,
#  '##oan': 1681,
#  '##1453': 2435,
#  'ps': 1371,
#  '##down': 620,
#  'pro2': 3452,
#  'lord': 8894,
#  'somplak': 9013,
#  'javhot': 7116,
#  'marisalingjaga': 9473,
#  'd2019': 4154,
#  'protests': 2439,
#  'busi': 4082,
#  'medsossdmsulsel_': 9696,
#  'edisi': 1999,
#  '##angs': 256,
#  '##artsp': 5886,
#  'berhasil': 3833,
#  'palest': 678,
#  '##und': 542,
#  'jatuh': 8225,
#  '##abali': 5629,
#  'instamom': 7079,
#  'radikalisme': 2507,
#  'odulu': 4448,
#  'pancen': 8969,
#  'infocuacariau': 8665,
#  'recov': 5908,
#  'marufam': 7030,
#  '##kur': 4943,
#  'reuni': 5907,
#  'untirtakampusderita': 8629,
#  'kuyang': 6732,
#  '##entris': 5922,
#  '##oftheday': 2421,
#  'wanitac': 7703,
#  '##oterkini': 7180,
#  'newnormal': 782,
#  '##asmad': 5343,
#  '##ojodoh': 6832,
#  '##ys': 4924,
#  'ahli': 7836,
#  '##uhan': 1474,
#  'gunakanmasker': 8089,
#  '##v_': 5101,
#  '##77': 5140,
#  'berkah': 1013,
#  'tel': 948,
#  'ngakakbanget': 7436,
#  'banyumaskeren': 8118,
#  'situasi': 7050,
#  '##book': 4996,
#  '##itad': 5370,
#  'reborn': 7949,
#  'gta': 4222,
#  '##catat': 5036,
#  'monolog': 7380,
#  '##polsek': 6038,
#  'rakornas': 3921,
#  'puspen': 7257,
#  'maiyah': 3896,
#  'miningforlife': 8517,
#  '##obet': 5929,
#  '##odoh': 890,
#  'ist': 785,
#  '##obloknya': 8398,
#  'boneka': 1143,
#  'jagajak': 3608,
#  'pri': 2768,
#  'jadwal': 3786,
#  'indonesiasehat': 3840,
#  '##ara24': 5881,
#  'str': 2303,
#  '##pekerja': 8353,
#  'daring': 6462,
#  '##ih': 228,
#  'um': 614,
#  '##mpi': 4792,
#  'bucin': 8723,
#  'naturephotography': 9475,
#  '##araan': 5880,
#  '3some': 8686,
#  '##abika': 5638,
#  '##ademy': 5570,
#  'worldwar': 7209,
#  'tolak_': 6127,
#  'tolakbayarukt': 8428,
#  'lo': 1613,
#  'puisipendek': 9560,
#  'alaikum': 9213,
#  'brobrogorebisan': 8678,
#  'motivasi': 3730,
#  'agen': 633,
#  'international': 7572,
#  '##imulus': 5582,
#  'photosho': 7685,
#  'crotmemek': 8747,
#  '8': 13,
#  'jangannular': 6578,
#  '##juangan': 6230,
#  'menangkanalquds': 8094,
#  '##alis': 310,
#  '##etika': 5750,
#  'pad': 1632,
#  'pangandaranhebat': 8132,
#  'ogah': 8952,
#  'dex': 2629,
#  '##nh': 4854,
#  'kunt': 4325,
#  'loyo': 7660,
#  '##ahi': 3089,
#  'kearsipan': 9364,
#  'wilayahpermotoran': 8572,
#  'casino': 4123,
#  'bersamamandiri': 7304,
#  '##dik': 199,
#  'jalur': 8854,
#  '##ebiri': 3209,
#  '##ps': 1401,
#  '##kamp': 4950,
#  'miotim': 8265,
#  '##umnya': 5486,
#  '##official': 6970,
#  'mday': 4395,
#  'bolaterpercaya': 7344,
#  'inv': 2246,
#  'help': 7888,
#  '##apitak': 5454,
#  '##alem': 5262,
#  'comm': 2496,
#  'kekeyi': 7656,
#  'tran': 753,
#  '##ratis': 801,
#  '##run': 841,
#  'xr': 2853,
#  '##erus': 5158,
#  '##anget': 5354,
#  'ig': 4268,
#  'rektordankemenagharusbijak': 9664,
#  'metro': 1533,
#  'bae': 7473,
#  'polreskubur': 3690,
#  'peremp': 1267,
#  '##toc': 4806,
#  '##utartangsel': 5677,
#  'liv': 396,
#  '##ind': 309,
#  '##eal': 1061,
#  'masfm': 6088,
#  '##1000': 8009,
#  'kriminal': 2480,
#  '##epert': 5939,
#  'terawan': 5951,
#  'infokesehatan': 8417,
#  'berbak': 3155,
#  '##ucu': 2337,
#  'its': 3454,
#  'fair': 3799,
#  'perbatasanjaman': 8039,
#  'bul': 1336,
#  '##ahter': 1237,
#  'bau': 4084,
#  'puspen_tni': 9519,
#  'tetapdirumah': 6715,
#  'esemka': 8776,
#  '##dikempot': 3978,
#  '##onlin': 2212,
#  '##rlam': 4739,
#  'kalistha': 8250,
#  'pancasi': 2777,
#  '##pasi': 2883,
#  'ferdianp': 3869,
#  'jogobumip': 7235,
#  '##ince': 3080,
#  'kangen': 2551,
#  'mendengar': 3775,
#  'downlo': 7363,
#  '##digital': 5473,
#  '##annya': 2203,
#  ...}

# %%
tokenizer.save("../data/tokenizers/tokenizer_hashtag.json")

# %%
output = tokenizer.encode("Sambut Berkah Ramadhan")

# %%
output.tokens
# Out:
# ['Sambut', 'Berkah', 'Ramadhan']
