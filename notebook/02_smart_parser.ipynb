# %%
import os
import glob
import json
from tqdm import tqdm

import pandas as pd

# %%
DATA_PATH = "../data"

# %%
tweets_file_paths = glob.glob(os.path.join(DATA_PATH, "tweets", "*.json"))

# %%
large_indo_file_paths = glob.glob(os.path.join(DATA_PATH, "7K_INDO", "*.json"))

# %%
file_paths = tweets_file_paths + large_indo_file_paths

# %%
len(file_paths)
# Out:
# 7202

# %%
def read_json(path):
    with open(path, 'r', encoding="utf-8") as file:
        return json.load(file)

# %%
data_text = []
for idx, path in tqdm(enumerate(file_paths)):
    data = read_json(path)
    string = "https://twitter.com/"+data["username"].replace("@", "")+" "+ "_"*10
    if len(data["tweets"]) > 0:
        
        screen_name = "name: "+data["tweets"][0]["user"]["name"] + "_"*10
        description = "description: "+data["tweets"][0]["user"]["description"] + "_"*10
        
        string = string + screen_name + description
        
    if len(data["tweets"]) > 0:
        data_used = data["tweets"]
    elif len(data["retweets"]) > 0:
        data_used = data["retweets"]
    elif len(data["replies"]) > 0:
        data_used = data["replies"]
    else:
        data_used = data["tweets"]
        
    for tweet in data_used[:5]:
        string = string + tweet["full_text"] + "_"*10

    string = string.replace("\n", " ")
    string = string.replace(",", " ")
    data_text.append({"ID": idx, "Text": string, "Label": ""})
# Out:
# 7202it [05:32, 21.64it/s]

# %%
d_tweets = pd.DataFrame(data_text, columns = ["ID", "Text", "Label"])

# %%
d_tweets
# Out:
#         ID                                               Text Label
# 0        0  https://twitter.com/212Ujee2 __________name: U...
# 1        1  https://twitter.com/2_1_N __________name: ᶜᵒʸ_...
# 2        2       https://twitter.com/305____Resta_ __________
# 3        3  https://twitter.com/Abdullah_SSoS __________na...
# 4        4  https://twitter.com/Adam_hasny __________name:...
# 5        5  https://twitter.com/addiems __________name: AD...
# 6        6             https://twitter.com/agussar __________
# 7        7  https://twitter.com/ainunnajib __________name:...
# 8        8  https://twitter.com/AirinAirin_NZ __________na...
# 9        9  https://twitter.com/AksiKamisan __________name...
# 10      10  https://twitter.com/AksiLangsung __________nam...
# 11      11  https://twitter.com/anandasukarlan __________n...
# 12      12  https://twitter.com/AndiArief__ __________name...
# 13      13  https://twitter.com/andre_rosiade __________na...
# 14      14  https://twitter.com/Anggraini_4yu __________na...
# 15      15     https://twitter.com/AnginLa49997994 __________
# 16      16  https://twitter.com/aniesbaswedan __________na...
# 17      17  https://twitter.com/AntoniRaja __________name:...
# 18      18  https://twitter.com/Anyaselalubenar __________...
# 19      19  https://twitter.com/areev_r __________name: AR...
# 20      20  https://twitter.com/ariel_heryanto __________n...
# 21      21  https://twitter.com/AS86222548 __________name:...
# 22      22  https://twitter.com/A_Komarud __________name: ...
# 23      23  https://twitter.com/B4ngToyyib __________name:...
# 24      24          https://twitter.com/badgaIdidi __________
# 25      25  https://twitter.com/Bagindo_Kopi __________nam...
# 26      26  https://twitter.com/basuki_btp __________name:...
# 27      27  https://twitter.com/BEAUTIFULYOONGO __________...
# 28      28  https://twitter.com/BNPB_Indonesia __________n...
# 29      29  https://twitter.com/BobbySurya85 __________nam...
# ...    ...                                                ...   ...
# 7172  7172  https://twitter.com/_d3nm4s_4j4h __________nam...
# 7173  7173  https://twitter.com/_duniabaru_ __________name...
# 7174  7174  https://twitter.com/_garuda501 __________name:...
# 7175  7175  https://twitter.com/_halahsiaaa __________name...
# 7176  7176       https://twitter.com/_halusinasii_ __________
# 7177  7177  https://twitter.com/_indraprtm __________name:...
# 7178  7178  https://twitter.com/_Irmayanti96_ __________na...
# 7179  7179          https://twitter.com/_Isnainnur __________
# 7180  7180  https://twitter.com/_jabangtutuko_ __________n...
# 7181  7181  https://twitter.com/_kesit_ __________name: Pa...
# 7182  7182  https://twitter.com/_khasmah __________name: R...
# 7183  7183  https://twitter.com/_kopipena __________name: ...
# 7184  7184  https://twitter.com/_linow __________name: ren...
# 7185  7185  https://twitter.com/_MandoW_ __________name: B...
# 7186  7186  https://twitter.com/_manusiadhoif __________na...
# 7187  7187        https://twitter.com/_MiftahFarid __________
# 7188  7188  https://twitter.com/_MRBTH_ __________name: M ...
# 7189  7189  https://twitter.com/_nnadewitt __________name:...
# 7190  7190  https://twitter.com/_no3nk_ __________name: 🇮🇩...
# 7191  7191  https://twitter.com/_pln_id __________name: PL...
# 7192  7192  https://twitter.com/_punakawan_ __________name...
# 7193  7193  https://twitter.com/_Ramadhan27 __________name...
# 7194  7194  https://twitter.com/_rikary __________name: Ri...
# 7195  7195  https://twitter.com/_sayangkuh__ __________nam...
# 7196  7196  https://twitter.com/_Slametkuncoro __________n...
# 7197  7197  https://twitter.com/_UNDERSCORE12 __________na...
# 7198  7198  https://twitter.com/_Wendywalters __________na...
# 7199  7199  https://twitter.com/__Brians__ __________name:...
# 7200  7200  https://twitter.com/__lelaamuslimin __________...
# 7201  7201  https://twitter.com/___denmasNg __________name...
#
# [7202 rows x 3 columns]

# %%
d_tweets.to_csv(os.path.join(DATA_PATH, "supports", "SMART_FORMATED_199.csv"), sep=",", index=False)
